# %%
import pandas as pd
import seaborn as sns
import numpy as np

import matplotlib
import matplotlib.pyplot as plt
plt.style.use('ggplot')
# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (12,8)
matplotlib.rcParams['figure.facecolor']='white'

# %%
df = pd.read_csv('movies.csv')
print(df.shape)
df.head()
# Out:
# (7668, 15)
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country      budget  \
# ...

# %%
df.isna().sum()
# Out:
# name           0
# rating        77
# genre          0
# year           0
# released       2
# score          3
# votes          3
# director       0
# writer         3
# star           1
# country        3
# budget      2171
# gross        189
# company       17
# runtime        4
# dtype: int64

# %%
for col in df.columns:
    pct = np.mean(df[col].isnull())
    print(col, '-', pct)
# Out:
# name - 0.0
# rating - 0.010041731872717789
# genre - 0.0
# year - 0.0
# released - 0.0002608242044861763
# score - 0.0003912363067292645
# votes - 0.0003912363067292645
# director - 0.0
# writer - 0.0003912363067292645
# star - 0.00013041210224308815
# country - 0.0003912363067292645
# budget - 0.2831246739697444
# gross - 0.02464788732394366
# company - 0.002217005738132499
# runtime - 0.0005216484089723526

# %%
df.dtypes
# Out:
# name         object
# rating       object
# genre        object
# year          int64
# released     object
# score       float64
# votes       float64
# director     object
# writer       object
# star         object
# country      object
# budget      float64
# gross       float64
# company      object
# runtime     float64
# dtype: object

# %%
df['budget'] = df['budget'].fillna(0)
df['budget'] = df['budget'].astype('int64')
df['gross'] = df['gross'].fillna(0)
df['gross'] = df['gross'].astype('int64')
df['votes'] = df['votes'].fillna(0)
df['votes'] = df['votes'].astype('int64')
df.dtypes
# Out:
# name         object
# rating       object
# genre        object
# year          int64
# released     object
# score       float64
# votes         int64
# director     object
# writer       object
# star         object
# country      object
# budget        int64
# gross         int64
# company      object
# runtime     float64
# dtype: object

# %%
df['released'][7000].split('(')[0].strip()
# Out:
# 'July 25, 2016'

# %%
df['released'] = df['released'].astype(str)

# %%
df['released'] = df['released'].apply(lambda x: x.split('(')[0].strip())
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#         released  score    votes         director                   writer  \
# 0  June 13, 1980    8.4   927000  Stanley Kubrick             Stephen King
# 1   July 2, 1980    5.8    65000   Randal Kleiser  Henry De Vere Stacpoole
# 2  June 20, 1980    8.7  1200000   Irvin Kershner           Leigh Brackett
# 3   July 2, 1980    7.7   221000     Jim Abrahams             Jim Abrahams
# 4  July 25, 1980    7.3   108000     Harold Ramis       Brian Doyle-Murray
#
# ...

# %%
df['yearCorrect'] = df['released'].str[-4:]
df
# Out:
#                                                 name rating      genre  year  \
# 0                                        The Shining      R      Drama  1980
# 1                                    The Blue Lagoon      R  Adventure  1980
# 2     Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                          Airplane!     PG     Comedy  1980
# 4                                         Caddyshack      R     Comedy  1980
# ...                                              ...    ...        ...   ...
# 7663                                    More to Life    NaN      Drama  2020
# 7664                                     Dream Round    NaN     Comedy  2020
# 7665                                   Saving Mbango    NaN      Drama  2020
# 7666                                    It's Just Us    NaN      Drama  2020
# 7667                                       Tee em el    NaN     Horror  2020
#
# ...

# %%
df.sort_values('gross', ascending=False)
# Out:
#                                             name rating    genre  year  \
# 5445                                      Avatar  PG-13   Action  2009
# 7445                           Avengers: Endgame  PG-13   Action  2019
# 3045                                     Titanic  PG-13    Drama  1997
# 6663  Star Wars: Episode VII - The Force Awakens  PG-13   Action  2015
# 7244                      Avengers: Infinity War  PG-13   Action  2018
# ...                                          ...    ...      ...   ...
# 1617                             Mortal Passions      R    Crime  1989
# 1614                              Edge of Sanity      R   Horror  1989
# 1606                                   I, Madman      R  Fantasy  1989
# 1601                        My Twentieth Century    NaN   Comedy  1989
# 7667                                   Tee em el    NaN   Horror  2020
#
#                released  score    votes        director              writer  \
# ...

# %%
# Drop Duplicates
df.drop_duplicates() # result is no duplicates
# Out:
#                                                 name rating      genre  year  \
# 0                                        The Shining      R      Drama  1980
# 1                                    The Blue Lagoon      R  Adventure  1980
# 2     Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                          Airplane!     PG     Comedy  1980
# 4                                         Caddyshack      R     Comedy  1980
# ...                                              ...    ...        ...   ...
# 7663                                    More to Life    NaN      Drama  2020
# 7664                                     Dream Round    NaN     Comedy  2020
# 7665                                   Saving Mbango    NaN      Drama  2020
# 7666                                    It's Just Us    NaN      Drama  2020
# 7667                                       Tee em el    NaN     Horror  2020
#
# ...

# %%
list(df.sort_values('company', ascending=False)['company'].unique())
# Out:
# ['thefyzz',
#  'micro_scope',
#  'iDeal Partners Film Fund',
#  'i5 Films',
#  'i am OTHER',
#  'erbp',
#  'double A Films',
#  'Zupnik-Curtis Enterprises',
#  'Zucker Brothers Productions',
#  'Zoetrope Studios',
#  'Zeta Entertainment',
#  'Zentropa International Norway',
#  'Zentropa Entertainments',
#  'Zenith Entertainment',
#  'Zazen Produções',
#  'ZapPictures',
#  'Zanuck/Brown Productions',
#  'Zacharias-Buhai Productions',
#  'Young Sung Production Co.',
#  'Young Hannibal Productions',
#  'Yellow Bird',
#  'Yash Raj Films',
#  'Yari Film Group Releasing',
#  'Yari Film Group (YFG)',
#  'Yale Productions',
#  'X-Filme Creative Pool',
#  'Wytwórnia Filmów Dokumentalnych i Fabularnych (WFDiF)',
#  'Worldview Entertainment',
#  'World of Wonder Productions',
#  'World Wrestling Entertainment (WWE)',
#  'World Film Services',
#  'Working Title Films',
#  'Working Dog',
#  'Woodline Productions',
#  "Wong Jing's Workshop Ltd.",
#  'Wiseau-Films',
#  'Winwood Productions',
# ...

# %%
sns.regplot(x='budget', y='gross', data=df, scatter_kws={'color':'navy'},
           line_kws={'color':'green'})
plt.title('Budget vs Gross')
plt.xlabel('Budget')
plt.ylabel('Gross')
plt.show()

# %%
# Pearson correlation
df.corr()
# Out:
#              year     score     votes    budget     gross   runtime
# year     1.000000  0.097995  0.222427  0.309212  0.261900  0.120811
# score    0.097995  1.000000  0.409182  0.055665  0.186392  0.399451
# votes    0.222427  0.409182  1.000000  0.486931  0.632870  0.309122
# budget   0.309212  0.055665  0.486931  1.000000  0.750157  0.269510
# gross    0.261900  0.186392  0.632870  0.750157  1.000000  0.245235
# runtime  0.120811  0.399451  0.309122  0.269510  0.245235  1.000000

# %%
sns.heatmap(df.corr(), annot=True)
plt.title('Correlation of numerical features')
# Out:
# Text(0.5, 1.0, 'Correlation of numerical features')

# %%
df_label = df.copy()

for col in df_label.columns:
    if df_label[col].dtype == "object":
        df_label[col] = df_label[col].astype('category')
        df_label[col] = df_label[col].cat.codes
df_label
# Out:
#       name  rating  genre  year  released  score    votes  director  writer  \
# 0     6587       6      6  1980      1510    8.4   927000      2589    4014
# 1     5573       6      1  1980      1311    5.8    65000      2269    1632
# 2     5142       4      0  1980      1568    8.7  1200000      1111    2567
# 3      286       4      4  1980      1311    7.7   221000      1301    2000
# 4     1027       6      4  1980      1360    7.3   108000      1054     521
# ...    ...     ...    ...   ...       ...    ...      ...       ...     ...
# 7663  3705      -1      6  2020      2582    3.1       18      1500    2289
# 7664  1678      -1      4  2020       975    4.7       36       774    2614
# 7665  4717      -1      6  2020       162    5.7       29      2061    2683
# 7666  2843      -1      6  2020      2462    NaN        0      1184    1824
# 7667  5394      -1     10  2020       344    5.7        7      2165    3344
#
# ...

# %%
df
# Out:
#                                                 name rating      genre  year  \
# 0                                        The Shining      R      Drama  1980
# 1                                    The Blue Lagoon      R  Adventure  1980
# 2     Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                          Airplane!     PG     Comedy  1980
# 4                                         Caddyshack      R     Comedy  1980
# ...                                              ...    ...        ...   ...
# 7663                                    More to Life    NaN      Drama  2020
# 7664                                     Dream Round    NaN     Comedy  2020
# 7665                                   Saving Mbango    NaN      Drama  2020
# 7666                                    It's Just Us    NaN      Drama  2020
# 7667                                       Tee em el    NaN     Horror  2020
#
# ...

# %%
sns.heatmap(df_label.corr(), annot=True)
# Out:
# <AxesSubplot:>

# %%
corr_label = df_label.corr()
corr_pairs = corr_label.unstack().sort_values(ascending=False)
pd.set_option('display.max_rows', None)
corr_pairs
# Out:
# name         name           1.000000
# rating       rating         1.000000
# runtime      runtime        1.000000
# company      company        1.000000
# gross        gross          1.000000
# budget       budget         1.000000
# country      country        1.000000
# star         star           1.000000
# writer       writer         1.000000
# director     director       1.000000
# votes        votes          1.000000
# score        score          1.000000
# released     released       1.000000
# year         year           1.000000
# genre        genre          1.000000
# yearCorrect  yearCorrect    1.000000
#              year           0.997295
# year         yearCorrect    0.997295
# budget       gross          0.750157
# gross        budget         0.750157
#              votes          0.632870
# votes        gross          0.632870
#              budget         0.486931
# budget       votes          0.486931
# votes        score          0.409182
# ...
